# %% [markdown]
# # The optimal location for a new shopping center - Code

# %% [markdown]
# ## Data collection and preparation

# %%
# list of postal codes for Milano
CAPs = [20121, 20122, 20123, 20124, 20125, 20126, 20127, 20128, 20129, 20131, 
        20132, 20133, 20134, 20135, 20136, 20137, 20138, 20139, 20141, 20142,
        20143, 20144, 20145, 20146, 20147, 20148, 20149, 20151, 20152, 20153,
        20154, 20155, 20156, 20157, 20158, 20159, 20161, 20162]

# %%
# construct a list that stores the data to construct the dataframe
# getting the latitude and longitude information with the Nominatim API
from geopy.geocoders import Nominatim
rows = []
geolocator = Nominatim(user_agent="coursera_project")
for c in CAPs:
    try:
        loc = geolocator.geocode("{0} Italy".format(c))
        rows.append([c, loc.address.split(",")[0], loc.latitude, loc.longitude])
    except:
        pass

# %%
# create the dataframe to store the information about the areas
import pandas as pd
milanAreas = pd.DataFrame(rows, columns=["CAP", "name", "latitude", "longitude"])
print(milanAreas.shape)
milanAreas
# Out:
# (32, 4)
#       CAP                     name   latitude  longitude
# 0   20121              Municipio 1  45.468740   9.182879
# 1   20122              Municipio 1  45.461931   9.196360
# 2   20123              Municipio 1  45.463221   9.177478
# 3   20124              Municipio 2  45.484780   9.202348
# 4   20125                    Greco  45.499673   9.204903
# 5   20126                  Segnano  45.513329   9.217614
# 6   20127                    Gorla  45.502510   9.222735
# 7   20128                 Precotto  45.514930   9.225498
# 8   20129              Municipio 3  45.471425   9.213726
# 9   20131              Città Studi  45.483760   9.222421
# 10  20132                  Cimiano  45.500142   9.238860
# 11  20133              Municipio 4  45.467552   9.226919
# 12  20134                 Lambrate  45.476655   9.243984
# 13  20135             Porta Romana  45.454655   9.211198
# 14  20136           Porta Ticinese  45.451155   9.179927
# 15  20137               Calvairate  45.455834   9.223354
# 16  20138               Morsenchio  45.444595   9.248136
# 17  20139              Municipio 4  45.439911   9.218294
# 18  20142  Quartiere Sant'Ambrogio  45.427615   9.165470
# 19  20143           San Cristoforo  45.446690   9.158657
# 20  20144              Municipio 6  45.457383   9.163339
# 21  20146              Lorenteggio  45.455110   9.139183
# 22  20147                   Arzaga  45.456770   9.130899
# 23  20149          Tre Torri-Fiera  45.479528   9.152944
# 24  20151               Boldinasco  45.495575   9.136475
# 25  20152              Sella Nuova  45.452183   9.107270
# 26  20154              Municipio 8  45.483010   9.174123
# 27  20155                  Bullona  45.491527   9.162498
# 28  20157           Quarto Oggiaro  45.512253   9.138147
# 29  20158                  Dergano  45.501537   9.172645
# 30  20159              Municipio 9  45.492812   9.187665
# 31  20162           Pratocentenaro  45.513087   9.197671

# %%
address = 'Piazza del Duomo, Duomo, Municipio 1, Milano, Lombardia, Italia'
loc = geolocator.geocode(address)
center_lat, center_long = loc.latitude, loc.longitude
print('The geograpical coordinate of the center of Milano are {}, {}.'.format(center_lat, center_long))
# Out:
# The geograpical coordinate of the center of Milano are 45.46420795, 9.190010308888969.

# %%
import folium
map_milano = folium.Map(location=[center_lat, center_long], zoom_start=12)
# add markers to map
for lat, lng, name, cap in zip(milanAreas['latitude'], milanAreas['longitude'], 
                                           milanAreas['name'], milanAreas['CAP']):
    label = '{}, {}'.format(cap, name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker([lat, lng], radius=8, popup=label, color='red', fill=True,
                        fill_color='#FF5733', fill_opacity=0.5, parse_html=False).add_to(map_milano)  
    
map_milano
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = '0WSSLBASAZEOMXIEUC5W4UDTLYADATYKYH1J0GBY4KE0LXVN' # your Foursquare ID
CLIENT_SECRET = 'XIFFL2HAJOUBHMQ2ABZDOUOLQE4MUIFZHEIJ05DS254KEYTD' # your Foursquare Secret
VERSION = '20200330' # Foursquare API version
LIMIT = 100

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 0WSSLBASAZEOMXIEUC5W4UDTLYADATYKYH1J0GBY4KE0LXVN
# CLIENT_SECRET:XIFFL2HAJOUBHMQ2ABZDOUOLQE4MUIFZHEIJ05DS254KEYTD

# %%
import requests

def getNearbyVenues(names, latitudes, longitudes, radius=1000, categoryID=None):
    
    venues_list=[]
    
    for n, name, lat, lng in zip(range(len(names)), names, latitudes, longitudes):
            
        if categoryID is None:
            # create the API request URL
            url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(
                CLIENT_ID, CLIENT_SECRET, lat, lng, VERSION, radius, LIMIT)
        else:
            url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}&categoryId={}'.format(
                CLIENT_ID, CLIENT_SECRET, lat, lng, VERSION, radius, LIMIT, categoryID)   
            
        # make the GET request
        results = requests.get(url).json()
        results = results["response"]['groups'][0]['items']
        if len(results) == 0:
            print("Warning! found no venue for neighboorhood nr. {1}: {0}".format(name, n))
        
        # return only relevant information for each nearby venue
        venues_list.append([ (name, lat, lng, v['venue']['name'], v['venue']['location']['lat'], 
                              v['venue']['location']['lng'], v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['CAP', 
                  'CAP Latitude', 
                  'CAP Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    print("\n Finished... a total number of {0} venues has been found!".format(len(nearby_venues)))
    return(nearby_venues)

# %%
# get all the venues
allVenues = getNearbyVenues(milanAreas["CAP"], milanAreas["latitude"], milanAreas["longitude"])
# Out:
#  Finished... a total number of 2572 venues has been found!

# %%
print(allVenues.shape)
allVenues.head()
# Out:
# (2572, 7)
#      CAP  CAP Latitude  CAP Longitude                           Venue  \
# 0  20121      45.46874       9.182879                 Piazza Castello
# 1  20121      45.46874       9.182879              Castello Sforzesco
# 2  20121      45.46874       9.182879  Fontana del Castello Sforzesco
# 3  20121      45.46874       9.182879              Giovanni Cova & C.
# 4  20121      45.46874       9.182879                         Antonia
#
#    Venue Latitude  Venue Longitude     Venue Category
# 0       45.468965         9.181312              Plaza
# 1       45.469545         9.180424             Castle
# 2       45.469237         9.180917           Fountain
# 3       45.468816         9.184121             Bakery
# 4       45.468890         9.184799  Accessories Store

# %%
# category ID of the category Shop & Service
categoryID = "4d4b7105d754a06378d81259"
# get all the Shop & Service venues
shopVenue = getNearbyVenues(milanAreas["CAP"], milanAreas["latitude"], milanAreas["longitude"], categoryID=categoryID)
# Out:
#  Finished... a total number of 1188 venues has been found!

# %%
print(shopVenue.shape)
shopVenue.head()
# Out:
# (1188, 7)
#      CAP  CAP Latitude  CAP Longitude              Venue  Venue Latitude  \
# 0  20121      45.46874       9.182879            Antonia       45.468890
# 1  20121      45.46874       9.182879           Gay Odin       45.466187
# 2  20121      45.46874       9.182879     New Old Camera       45.467359
# 3  20121      45.46874       9.182879  Fabriano Boutique       45.470025
# 4  20121      45.46874       9.182879       Flying Tiger       45.465945
#
#    Venue Longitude     Venue Category
# 0         9.184799  Accessories Store
# 1         9.180801     Chocolate Shop
# 2         9.184171       Camera Store
# 3         9.184987   Stationery Store
# 4         9.184850          Gift Shop

# %% [markdown]
# ## First step: clustering of all the areas of Milano

# %%
# count the total number of shops per each area defined and labelled by its CAP
shopVenue_count = shopVenue[["CAP","Venue"]].groupby('CAP').count().reset_index()
shopVenue_count.columns = ["CAP", "Shop Total Nr"]
shopVenue_count.set_index("CAP", inplace=True)

# count the number of shop types present in each area and labelled by its CAP
shopVenue_countunique = shopVenue[["CAP","Venue Category"]].groupby('CAP')["Venue Category"].nunique().reset_index()
shopVenue_countunique.columns = ["CAP", "Shop Type Nr"]
shopVenue_countunique.set_index("CAP", inplace=True)

# join the two columns in a single dataframe
shopVenue_count = shopVenue_count.join(shopVenue_countunique, on="CAP", lsuffix='', rsuffix='')
shopVenue_count.reset_index()

print(shopVenue_count.shape)
shopVenue_count.head()
# Out:
# (34, 2)
#        Shop Total Nr  Shop Type Nr
# CAP
# 20121            100            34
# 20122            100            27
# 20123             81            29
# 20124             86            36
# 20125             23            16

# %%
# now determine the total number of venues in each area, by counting the elements in the allVenues dataframe
allVenue_count = allVenues[["CAP","Venue"]].groupby('CAP').count()
allVenue_count.columns = ["Venue Total Nr"]

print(allVenue_count.shape)
allVenue_count.head()
# Out:
# (34, 1)
#        Venue Total Nr
# CAP
# 20121             100
# 20122             100
# 20123             100
# 20124              82
# 20125              82

# %%
# now compute the distance between each neighborhood center and the city center using the geidesic distance
# implemented in the geopy library

import geopy.distance

# coordinates of the city center
center = (center_lat, center_long)

# loop over the neighborhoods and compute the distance
rows = []
for cap, lat, long in zip(milanAreas["CAP"], milanAreas["latitude"], milanAreas["longitude"]):
    neighborhood = (lat, long)
    rows.append([cap, geopy.distance.distance(center, neighborhood).km])
    
# create the dataframe to store the information about the areas
distances = pd.DataFrame(rows, columns=["CAP", "distance"]).set_index("CAP")

print(distances.shape)
distances.head()
# Out:
# (34, 1)
#        distance
# CAP
# 20121  0.751457
# 20122  0.557364
# 20123  0.986282
# 20124  2.481610
# 20125  4.110022

# %%
# now join all the tables in a single dataframe
df1 = shopVenue_count.join(allVenue_count, on="CAP", lsuffix='', rsuffix='').join(
    distances, on="CAP", lsuffix='', rsuffix='')

print(df1.shape)
df1
# Out:
# (34, 4)
#        Shop Total Nr  Shop Type Nr  Venue Total Nr  distance
# CAP
# 20121            100            34             100  0.751457
# 20122            100            27             100  0.557364
# 20123             81            29             100  0.986282
# 20124             86            36              82  2.481610
# 20125             23            16              82  4.110022
# 20126             20            15              94  5.870387
# 20127             13            10              64  4.966618
# 20128             18            13              55  6.282979
# 20129             47            27             100  2.020685
# 20131             64            35              78  3.338398
# 20132             20            15              54  5.525985
# 20133             29            19             100  2.910310
# 20134             15            13              74  4.441639
# 20135             51            28             100  1.968077
# 20136             43            23             100  1.651284
# 20137             34            20             100  2.769024
# 20138              8             6              21  5.042223
# 20139             31            22              80  3.490976
# 20142              6             4              23  4.497375
# 20143             41            25             100  3.131315
# 20144             39            24             100  2.219633
# 20146             35            18              65  4.102013
# 20147             18            14              55  4.696594
# 20149             38            26             100  3.361550
# 20151             37            23              90  5.447322
# 20152              5             3              19  6.608144
# 20154             37            24             100  2.431102
# 20155             30            19             100  3.721048
# 20156             11             9              40  5.338463
# 20157              8             3              16  6.704582
# 20158             32            19              90  4.365273
# 20159             45            26             100  3.184370
# 20161             14             8              32  6.210545
# 20162              9             7              58  5.465445

# %%
# now cluster data

# set number of clusters
kclusters = 5

# import k-means from clustering stage
from sklearn.cluster import KMeans

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df1)

# check cluster labels generated for each row in the dataframe
kmeans.labels_
# Out:
# array([2, 2, 2, 2, 0, 0, 3, 3, 4, 2, 3, 0, 3, 4, 4, 4, 1, 0, 1, 4, 4, 3,
#        3, 4, 4, 1, 4, 0, 1, 1, 0, 4, 1, 3], dtype=int32)

# %%
# add the cluster column to the dataframe
df1["cluster"] = kmeans.labels_

# add the latitude and longitude columns to the dataframe
milanAreas
df1 = df1.join(milanAreas.set_index("CAP"), on="CAP", lsuffix='', rsuffix='')
df1.head()

df1.reset_index(inplace=True)

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
import numpy as np

# define a function to plot map with colored clusters
def plot_map_clusters(df):
    
    # create map
    map_milano = folium.Map(location=[center_lat, center_long], zoom_start=11)
    
    # set color scheme for the clusters
    x = np.arange(kclusters)
    ys = [i + x + (i*x)**2 for i in range(kclusters)]
    colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
    rainbow = [colors.rgb2hex(i) for i in colors_array]

    # add markers to the map
    markers_colors = []
    for lat, lon, cap, name, cluster in zip(df['latitude'], df['longitude'], df['CAP'], df["name"], df['cluster']):
        label = folium.Popup("{0}, {1} - Cluster {2}".format(name, cap, cluster), parse_html=True)
        folium.CircleMarker([lat, lon], radius=8, popup=label, color=rainbow[cluster-1], fill=True,
                        fill_color=rainbow[cluster-1], fill_opacity=0.7, parse_html=False).add_to(map_milano)  
       
    return map_milano

# %%
plot_map_clusters(df1)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df1.loc[df1['cluster'] == 0, :] # red, group 3
# Out:
#       CAP  Shop Total Nr  Shop Type Nr  Venue Total Nr  distance  cluster  \
# 4   20125             23            16              82  4.110022        0
# 5   20126             20            15              94  5.870387        0
# 11  20133             29            19             100  2.910310        0
# 17  20139             31            22              80  3.490976        0
# 27  20155             30            19             100  3.721048        0
# 30  20158             32            19              90  4.365273        0
#
#            name   latitude  longitude
# 4         Greco  45.499673   9.204903
# 5       Segnano  45.513329   9.217614
# 11  Municipio 4  45.467552   9.226919
# 17  Municipio 4  45.439911   9.218294
# 27      Bullona  45.491527   9.162498
# 30      Dergano  45.501537   9.172645

# %%
df1.loc[df1['cluster'] == 1, :] # violet, group 5
# Out:
#       CAP  Shop Total Nr  Shop Type Nr  Venue Total Nr  distance  cluster  \
# 16  20138              8             6              21  5.042223        1
# 18  20142              6             4              23  4.497375        1
# 25  20152              5             3              19  6.608144        1
# 28  20156             11             9              40  5.338463        1
# 29  20157              8             3              16  6.704582        1
# 32  20161             14             8              32  6.210545        1
#
#                        name   latitude  longitude
# 16               Morsenchio  45.444595   9.248136
# 18  Quartiere Sant'Ambrogio  45.427615   9.165470
# 25              Sella Nuova  45.452183   9.107270
# 28             Villapizzone  45.503402   9.150537
# 29           Quarto Oggiaro  45.512253   9.138147
# 32                   Affori  45.518615   9.171888

# %%
df1.loc[df1['cluster'] == 2, :] # cyan, group 1
# Out:
#      CAP  Shop Total Nr  Shop Type Nr  Venue Total Nr  distance  cluster  \
# 0  20121            100            34             100  0.751457        2
# 1  20122            100            27             100  0.557364        2
# 2  20123             81            29             100  0.986282        2
# 3  20124             86            36              82  2.481610        2
# 9  20131             64            35              78  3.338398        2
#
#           name   latitude  longitude
# 0  Municipio 1  45.468740   9.182879
# 1  Municipio 1  45.461931   9.196360
# 2  Municipio 1  45.463221   9.177478
# 3  Municipio 2  45.484780   9.202348
# 9  Città Studi  45.483760   9.222421

# %%
df1.loc[df1['cluster'] == 3, :] # green, group 4
# Out:
#       CAP  Shop Total Nr  Shop Type Nr  Venue Total Nr  distance  cluster  \
# 6   20127             13            10              64  4.966618        3
# 7   20128             18            13              55  6.282979        3
# 10  20132             20            15              54  5.525985        3
# 12  20134             15            13              74  4.441639        3
# 21  20146             35            18              65  4.102013        3
# 22  20147             18            14              55  4.696594        3
# 33  20162              9             7              58  5.465445        3
#
#               name   latitude  longitude
# 6            Gorla  45.502510   9.222735
# 7         Precotto  45.514930   9.225498
# 10         Cimiano  45.500142   9.238860
# 12        Lambrate  45.476655   9.243984
# 21     Lorenteggio  45.455110   9.139183
# 22          Arzaga  45.456770   9.130899
# 33  Pratocentenaro  45.513087   9.197671

# %%
df1.loc[df1['cluster'] == 4, :] # orange, group 2
# Out:
#       CAP  Shop Total Nr  Shop Type Nr  Venue Total Nr  distance  cluster  \
# 8   20129             47            27             100  2.020685        4
# 13  20135             51            28             100  1.968077        4
# 14  20136             43            23             100  1.651284        4
# 15  20137             34            20             100  2.769024        4
# 19  20143             41            25             100  3.131315        4
# 20  20144             39            24             100  2.219633        4
# 23  20149             38            26             100  3.361550        4
# 24  20151             37            23              90  5.447322        4
# 26  20154             37            24             100  2.431102        4
# 31  20159             45            26             100  3.184370        4
#
#                name   latitude  longitude
# 8       Municipio 3  45.471425   9.213726
# 13     Porta Romana  45.454655   9.211198
# 14   Porta Ticinese  45.451155   9.179927
# 15       Calvairate  45.455834   9.223354
# 19   San Cristoforo  45.446690   9.158657
# 20      Municipio 6  45.457383   9.163339
# 23  Tre Torri-Fiera  45.479528   9.152944
# 24       Boldinasco  45.495575   9.136475
# 26      Municipio 8  45.483010   9.174123
# 31      Municipio 9  45.492812   9.187665

# %% [markdown]
# The analysis show that the areas of Milano can be classified in this way:
#
# 1. central areas, with a **large number of venues**, a **large number of shops** of diverse type (cluster 2, color cyan)
# 2. non central areas, with a **large number of venues**, and a **relatively high number of shops** still of diverse type (cluster 4, color orange)
# 3. non central areas, with a **moderate number of shops** and a **large number of venues** (cluster 0, color red)
# 4. non central areas, with a **moderate number of shops** and a **moderate number of venues** (cluster 3, color green)
# 5. non central areas, with a **small number of shops and venues** (cluster 1, violet)

# %% [markdown]
# Evidently, the interesting areas for opening a new shopping center would be the 3rd and 4th group, with a particular preference for the 3rd group. Areas of the 1st and 2nd group are already too crowded in terms of shops, while areas of the 5th group are too peripheral, as shown by the small number of venues.

# %% [markdown]
# ### Second step: analysis of the shops in the interesting areas

# %% [markdown]
# We now extract the interesting areas and create a new dataframe with the shops from these areas only

# %%
interestingCAPs = list(df1.loc[df1['cluster'] == 3, :]["CAP"]) + list(df1.loc[df1['cluster'] == 0, :]["CAP"])
print(interestingCAPs)
# Out:
# [20127, 20128, 20132, 20134, 20146, 20147, 20162, 20125, 20126, 20133, 20139, 20155, 20158]

# %%
shopVenue_selected = shopVenue[shopVenue["CAP"].isin(interestingCAPs)]

print(shopVenue_selected.shape)
shopVenue_selected.head()
# Out:
# (293, 7)
#        CAP  CAP Latitude  CAP Longitude              Venue  Venue Latitude  \
# 367  20125     45.499673       9.204903    Farmacia Falqui       45.500670
# 368  20125     45.499673       9.204903          Esselunga       45.499101
# 369  20125     45.499673       9.204903  Carrefour Express       45.492574
# 370  20125     45.499673       9.204903          LD Market       45.499847
# 371  20125     45.499673       9.204903           Pet Stop       45.500918
#
#      Venue Longitude     Venue Category
# 367         9.197202           Pharmacy
# 368         9.195828        Supermarket
# 369         9.206591  Convenience Store
# 370         9.210104        Supermarket
# 371         9.209864          Pet Store

# %%
print('There are {} uniques categories.'.format(len(shopVenue_selected['Venue Category'].unique())))
# Out:
# There are 59 uniques categories.

# %%
# one hot encoding
shopVenue_dummy = pd.get_dummies(shopVenue_selected[['Venue Category']], prefix="", prefix_sep="")
print(shopVenue_dummy.shape)

# add neighborhood column back to dataframe
shopVenue_dummy['CAP'] = shopVenue_selected['CAP'] 

# move neighborhood column to the first column
collist = list(shopVenue_dummy.columns)
collist.remove('CAP')
shopVenue_dummy = shopVenue_dummy[['CAP'] + collist]

print(shopVenue_dummy.shape)
shopVenue_dummy.head()
# Out:
# (293, 59)
# (293, 60)
#        CAP  Accessories Store  Arts & Crafts Store  Auto Garage  \
# 367  20125                  0                    0            0
# 368  20125                  0                    0            0
# 369  20125                  0                    0            0
# 370  20125                  0                    0            0
# 371  20125                  0                    0            0
#
#      Auto Workshop  Betting Shop  Bookstore  Boutique  Business Service  \
# 367              0             0          0         0                 0
# 368              0             0          0         0                 0
# 369              0             0          0         0                 0
# 370              0             0          0         0                 0
# 371              0             0          0         0                 0
#
#      Candy Store      ...        Shop & Service  Shopping Mall  Smoke Shop  \
# 367            0      ...                     0              0           0
# 368            0      ...                     0              0           0
# 369            0      ...                     0              0           0
# 370            0      ...                     0              0           0
# 371            0      ...                     0              0           0
#
#      Sporting Goods Shop  Supermarket  Thrift / Vintage Store  \
# 367                    0            0                       0
# 368                    0            1                       0
# 369                    0            0                       0
# 370                    0            1                       0
# 371                    0            0                       0
#
#      Toy / Game Store  Video Game Store  Wine Shop  Women's Store
# 367                 0                 0          0              0
# 368                 0                 0          0              0
# 369                 0                 0          0              0
# 370                 0                 0          0              0
# 371                 0                 0          0              0
#
# [5 rows x 60 columns]

# %%
# now sum the data by CAP
shopVenue_grouped = shopVenue_dummy.groupby('CAP').sum().reset_index()
shopVenue_grouped.set_index("CAP", inplace=True)

shopVenue_grouped.shape
shopVenue_grouped
# Out:
#        Accessories Store  Arts & Crafts Store  Auto Garage  Auto Workshop  \
# CAP
# 20125                  0                    0            0              0
# 20126                  0                    1            0              0
# 20127                  0                    2            0              0
# 20128                  0                    0            0              0
# 20132                  0                    0            0              0
# 20133                  0                    0            0              0
# 20134                  0                    1            0              0
# 20139                  0                    0            1              0
# 20146                  0                    0            0              0
# 20147                  0                    1            0              0
# 20155                  1                    0            0              0
# 20158                  1                    0            0              1
# 20162                  0                    1            0              0
#
#        Betting Shop  Bookstore  Boutique  Business Service  Candy Store  \
# CAP
# 20125             0          1         0                 0            0
# 20126             0          0         0                 0            0
# 20127             0          0         0                 0            0
# 20128             0          0         0                 0            0
# 20132             0          0         0                 0            0
# 20133             0          1         0                 1            0
# 20134             0          0         0                 0            1
# 20139             0          2         1                 2            0
# 20146             0          0         0                 0            0
# 20147             0          0         0                 0            0
# 20155             1          0         0                 1            0
# 20158             0          2         1                 0            0
# 20162             0          0         0                 0            0
#
#        Cheese Shop      ...        Shop & Service  Shopping Mall  Smoke Shop  \
# CAP                     ...
# 20125            0      ...                     0              0           0
# 20126            0      ...                     1              1           0
# 20127            0      ...                     0              0           0
# 20128            0      ...                     1              1           0
# 20132            0      ...                     0              0           0
# 20133            0      ...                     0              1           1
# 20134            0      ...                     0              0           0
# 20139            0      ...                     0              0           1
# 20146            0      ...                     0              0           0
# 20147            0      ...                     0              0           0
# 20155            2      ...                     1              0           3
# 20158            0      ...                     1              0           4
# 20162            0      ...                     0              1           0
#
#        Sporting Goods Shop  Supermarket  Thrift / Vintage Store  \
# CAP
# 20125                    0            5                       0
# 20126                    0            4                       0
# 20127                    0            2                       0
# 20128                    0            3                       0
# 20132                    1            5                       0
# 20133                    0            4                       0
# 20134                    0            2                       1
# 20139                    0            4                       0
# 20146                    2            7                       0
# 20147                    2            4                       0
# 20155                    1            4                       0
# 20158                    0            6                       0
# 20162                    0            3                       0
#
#        Toy / Game Store  Video Game Store  Wine Shop  Women's Store
# CAP
# 20125                 0                 0          0              0
# 20126                 0                 1          0              1
# 20127                 0                 0          2              0
# 20128                 1                 0          0              1
# 20132                 0                 0          0              0
# 20133                 0                 0          2              1
# 20134                 0                 0          0              1
# 20139                 0                 0          0              0
# 20146                 0                 0          0              0
# 20147                 0                 0          0              0
# 20155                 1                 0          2              0
# 20158                 0                 0          0              0
# 20162                 0                 0          0              0
#
# [13 rows x 59 columns]

# %%
# set number of clusters
kclusters = 4

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(shopVenue_grouped)

# check cluster labels generated for each row in the dataframe
kmeans.labels_
# Out:
# array([3, 0, 0, 0, 0, 3, 0, 3, 1, 0, 0, 2, 0], dtype=int32)

# %%
# add cluster label to the shopVenue_grouped dataframe
shopVenue_grouped["cluster"] = [ int(cluster) for cluster in kmeans.labels_]
shopVenue_grouped.head()
# Out:
#        Accessories Store  Arts & Crafts Store  Auto Garage  Auto Workshop  \
# CAP
# 20125                  0                    0            0              0
# 20126                  0                    1            0              0
# 20127                  0                    2            0              0
# 20128                  0                    0            0              0
# 20132                  0                    0            0              0
#
#        Betting Shop  Bookstore  Boutique  Business Service  Candy Store  \
# CAP
# 20125             0          1         0                 0            0
# 20126             0          0         0                 0            0
# 20127             0          0         0                 0            0
# 20128             0          0         0                 0            0
# 20132             0          0         0                 0            0
#
#        Cheese Shop   ...     Shopping Mall  Smoke Shop  Sporting Goods Shop  \
# CAP                  ...
# 20125            0   ...                 0           0                    0
# 20126            0   ...                 1           0                    0
# 20127            0   ...                 0           0                    0
# 20128            0   ...                 1           0                    0
# 20132            0   ...                 0           0                    1
#
#        Supermarket  Thrift / Vintage Store  Toy / Game Store  \
# CAP
# 20125            5                       0                 0
# 20126            4                       0                 0
# 20127            2                       0                 0
# 20128            3                       0                 1
# 20132            5                       0                 0
#
#        Video Game Store  Wine Shop  Women's Store  cluster
# CAP
# 20125                 0          0              0        3
# 20126                 1          0              1        0
# 20127                 0          2              0        0
# 20128                 0          0              1        0
# 20132                 0          0              0        0
#
# [5 rows x 60 columns]

# %%
milanAreas_selected = milanAreas[milanAreas["CAP"].isin(interestingCAPs)]
milanAreas_selected.set_index("CAP", inplace=True)

milanAreas_selected = milanAreas_selected.join(shopVenue_grouped["cluster"], on="CAP", lsuffix='', rsuffix='')
milanAreas_selected.reset_index(inplace=True)
milanAreas_selected
# Out:
#       CAP            name   latitude  longitude  cluster
# 0   20125           Greco  45.499673   9.204903        3
# 1   20126         Segnano  45.513329   9.217614        0
# 2   20127           Gorla  45.502510   9.222735        0
# 3   20128        Precotto  45.514930   9.225498        0
# 4   20132         Cimiano  45.500142   9.238860        0
# 5   20133     Municipio 4  45.467552   9.226919        3
# 6   20134        Lambrate  45.476655   9.243984        0
# 7   20139     Municipio 4  45.439911   9.218294        3
# 8   20146     Lorenteggio  45.455110   9.139183        1
# 9   20147          Arzaga  45.456770   9.130899        0
# 10  20155         Bullona  45.491527   9.162498        0
# 11  20158         Dergano  45.501537   9.172645        2
# 12  20162  Pratocentenaro  45.513087   9.197671        0

# %%
plot_map_clusters(milanAreas_selected)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# create a new dataframe
shoplist = pd.DataFrame()

for cap in shopVenue_grouped.index:
    row_sorted = shopVenue_grouped.loc[cap, :].sort_values(ascending=False)
    shoplist.loc[cap,"cluster"] = shopVenue_grouped.loc[cap,"cluster"]
    i = 1
    for shop in row_sorted.index:
        if row_sorted[shop] > 0 and shop != "cluster":
            shoplist.loc[cap,i] = "{} ({})".format(shop, row_sorted[shop])
            i += 1

shoplist["cluster"] = shoplist["cluster"].astype(int)

# %%
shoplist.loc[shoplist['cluster'] == 0, :] # red, group
# Out:
#        cluster                   1                           2  \
# 20126        0     Supermarket (4)  Furniture / Home Store (2)
# 20127        0       Wine Shop (2)     Arts & Crafts Store (2)
# 20128        0     Supermarket (3)  Furniture / Home Store (2)
# 20132        0     Supermarket (5)       Electronics Store (2)
# 20134        0  Farmers Market (2)             Supermarket (2)
# 20147        0     Supermarket (4)     Sporting Goods Shop (2)
# 20155        0     Supermarket (4)              Smoke Shop (3)
# 20162        0     Supermarket (3)                Pharmacy (1)
#
#                            3                   4  \
# 20126  Food & Drink Shop (2)       Pet Store (1)
# 20127        Supermarket (2)        Pharmacy (1)
# 20128  Food & Drink Shop (2)  Cosmetics Shop (2)
# 20132   Recording Studio (1)     Outlet Mall (1)
# 20134           Pharmacy (1)     Candy Store (1)
# 20147         Hobby Shop (1)      Shoe Store (1)
# 20155  Health Food Store (2)          Market (2)
# 20162  Other Repair Shop (1)   Shopping Mall (1)
#
#                                        5                      6  \
# 20126                 Shop & Service (1)  Electronics Store (1)
# 20127               Insurance Office (1)          Pet Store (1)
# 20128                 Shop & Service (1)      Women's Store (1)
# 20132               Department Store (1)     Cosmetics Shop (1)
# 20134                  Women's Store (1)  Mobile Phone Shop (1)
# 20147               Insurance Office (1)        Flea Market (1)
# 20155                      Wine Shop (2)  Electronics Store (2)
# 20162  Paper / Office Supplies Store (1)   Department Store (1)
#
#                              7                                  8  \
# 20126               Market (1)  Paper / Office Supplies Store (1)
# 20127    Convenience Store (1)                     Kids Store (1)
# 20128               Market (1)              Electronics Store (1)
# 20132    Mobile Phone Shop (1)     Construction & Landscaping (1)
# 20134         Optical Shop (1)              Electronics Store (1)
# 20147         Optical Shop (1)              Electronics Store (1)
# 20155          Cheese Shop (2)                    IT Services (2)
# 20162  Arts & Crafts Store (1)                                NaN
#
#                                        9 ...                            13  \
# 20126                       Pharmacy (1) ...   Health & Beauty Service (1)
# 20127              Food & Drink Shop (1) ...                           NaN
# 20128              Convenience Store (1) ...          Toy / Game Store (1)
# 20132                 Clothing Store (1) ...         Food & Drink Shop (1)
# 20134  Paper / Office Supplies Store (1) ...    Thrift / Vintage Store (1)
# 20147                 Cosmetics Shop (1) ...             Grocery Store (1)
# 20155              Convenience Store (1) ...         Accessories Store (1)
# 20162                                NaN ...                           NaN
#
#                                 14                       15  \
# 20126         Video Game Store (1)  Arts & Crafts Store (1)
# 20127                          NaN                      NaN
# 20128                          NaN                      NaN
# 20132  Health & Beauty Service (1)           Shoe Store (1)
# 20134                          NaN                      NaN
# 20147      Arts & Crafts Store (1)                      NaN
# 20155             Betting Shop (1)       Shop & Service (1)
# 20162                          NaN                      NaN
#
#                             16                    17                     18  \
# 20126                      NaN                   NaN                    NaN
# 20127                      NaN                   NaN                    NaN
# 20128                      NaN                   NaN                    NaN
# 20132                      NaN                   NaN                    NaN
# 20134                      NaN                   NaN                    NaN
# 20147                      NaN                   NaN                    NaN
# 20155  Sporting Goods Shop (1)  Toy / Game Store (1)  Food & Drink Shop (1)
# 20162                      NaN                   NaN                    NaN
#
#                           19   20   21   22
# 20126                    NaN  NaN  NaN  NaN
# 20127                    NaN  NaN  NaN  NaN
# 20128                    NaN  NaN  NaN  NaN
# 20132                    NaN  NaN  NaN  NaN
# 20134                    NaN  NaN  NaN  NaN
# 20147                    NaN  NaN  NaN  NaN
# 20155  Mobile Phone Shop (1)  NaN  NaN  NaN
# 20162                    NaN  NaN  NaN  NaN
#
# [8 rows x 23 columns]

# %%
shoplist.loc[shoplist['cluster'] == 1, :] # violet, group
# Out:
#        cluster                1             2                      3  \
# 20146        1  Supermarket (7)  Pharmacy (5)  Mobile Phone Shop (2)
#
#                     4                       5                        6  \
# 20146  Shoe Store (2)  Photography Studio (2)  Sporting Goods Shop (2)
#
#                            7                 8                  9 ...   \
# 20146  Electronics Store (2)  Optical Shop (2)  Grocery Store (2) ...
#
#                          13                  14                     15  \
# 20146  Department Store (1)  Cosmetics Shop (1)  Convenience Store (1)
#
#                        16                     17              18   19   20  \
# 20146  Clothing Store (1)  Food & Drink Shop (1)  Hobby Shop (1)  NaN  NaN
#
#         21   22
# 20146  NaN  NaN
#
# [1 rows x 23 columns]

# %%
shoplist.loc[shoplist['cluster'] == 2, :] # cyan, group
# Out:
#        cluster                1               2             3              4  \
# 20158        2  Supermarket (6)  Smoke Shop (4)  Pharmacy (2)  Bookstore (2)
#
#                         5                      6  \
# 20158  Cosmetics Shop (2)  Mobile Phone Shop (2)
#
#                                        7                  8             9  \
# 20158  Paper / Office Supplies Store (2)  Auto Workshop (1)  Boutique (1)
#
#       ...                 13             14              15  \
# 20158 ...   Outlet Store (1)  Pet Store (1)  Hobby Shop (1)
#
#                           16                  17                  18  \
# 20158  Accessories Store (1)  Shipping Store (1)  Shop & Service (1)
#
#                    19   20   21   22
# 20158  Print Shop (1)  NaN  NaN  NaN
#
# [1 rows x 23 columns]

# %%
shoplist.loc[shoplist['cluster'] == 3, :] # yellow, group
# Out:
#        cluster                      1                   2  \
# 20125        3        Supermarket (5)  Clothing Store (3)
# 20133        3  Convenience Store (4)     Supermarket (4)
# 20139        3        Supermarket (4)       Bookstore (2)
#
#                            3               4                      5  \
# 20125           Pharmacy (2)   Gift Shop (1)  Convenience Store (1)
# 20133       Optical Shop (2)   Wine Shop (2)          Pet Store (2)
# 20139  Electronics Store (2)  Kids Store (2)     Clothing Store (2)
#
#                            6                     7                      8  \
# 20125  Other Repair Shop (1)    Farmers Market (1)  Electronics Store (1)
# 20133     Clothing Store (2)  Business Service (1)   Insurance Office (1)
# 20139   Business Service (2)       Film Studio (2)         Smoke Shop (1)
#
#                      9         ...                             13  \
# 20125  Fish Market (1)         ...               Optical Shop (1)
# 20133  IT Services (1)         ...          Food & Drink Shop (1)
# 20139     Boutique (1)         ...                Flower Shop (1)
#
#                           14                 15               16  \
# 20125         Kids Store (1)    Flower Shop (1)    Bookstore (1)
# 20133          Bookstore (1)  Shopping Mall (1)   Smoke Shop (1)
# 20139  Health Food Store (1)       Pharmacy (1)  Flea Market (1)
#
#                           17               18                    19  \
# 20125                    NaN              NaN                   NaN
# 20133      Grocery Store (1)    Gift Shop (1)       Flower Shop (1)
# 20139  Convenience Store (1)  Auto Garage (1)  Department Store (1)
#
#                                 20                  21                  22
# 20125                          NaN                 NaN                 NaN
# 20133                          NaN                 NaN                 NaN
# 20139  Health & Beauty Service (1)  Lingerie Store (1)  Shipping Store (1)
#
# [3 rows x 23 columns]
